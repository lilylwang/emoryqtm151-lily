# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import psycopg2
import sqlalchemy as sa
from   sqlalchemy.engine import URL
from   sqlalchemy import text

# %%
url_server = URL.create(
    "postgresql",
    host = 'localhost',
    database = 'postgres',
    username = 'postgres',
    port = 5433,
    password  = '12345')

con = sa.create_engine(url_server).connect()

# %%
drivers = pd.read_csv("data_clean/drivers.csv")
qualifying = pd.read_csv("data_raw/qualifying.csv")
#results = pd.read_csv("data_raw/results.csv")

# %%
# Clean drivers table
#display(drivers)
drivers.dtypes

# drivers["number"] = drivers["number"].replace(["\\N"], [np.nan])
# drivers["number"] = pd.to_numeric(drivers["number"])

# drivers["code"] = drivers["code"].replace(["\\N"], [np.nan])
#drivers["dob"] = pd.to_datetime(drivers["dob"], format="%Y-%m-%d")

# drivers = drivers[["driverId", "driverRef", "number", "code", "forename", "surname", "dob", "nationality", "url"]]

# %%
# Clean qualifying
qualifying.dtypes
#qualifying["q1"] = qualifying["q1"].replace(["\\N"], [np.nan])
#qualifying["q2"] = qualifying["q2"].replace(["\\N"], [np.nan])
#qualifying["q3"] = qualifying["q3"].replace(["\\N"], [np.nan])
qualifying["q1"] = pd.to_datetime(qualifying["q1"], format="%I:%M.%l")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\lilwa\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\tslibs\strptime.pyx:109, in pandas._libs.tslibs.strptime.array_strptime()
#
# File c:\Users\lilwa\AppData\Local\Programs\Python\Python311\Lib\_strptime.py:263, in TimeRE.compile(self, format)
#     262 """Return a compiled re object for the format string."""
# --> 263 return re_compile(self.pattern(format), IGNORECASE)
#
# File c:\Users\lilwa\AppData\Local\Programs\Python\Python311\Lib\_strptime.py:257, in TimeRE.pattern(self, format)
#     254 directive_index = format.index('%')+1
#     255 processed_format = "%s%s%s" % (processed_format,
#     256                                format[:directive_index-1],
# --> 257                                self[format[directive_index]])
#     258 format = format[directive_index+1:]
#
# ...

# %%
display(results)
results.dtypes
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# ...

# %%
drivers.to_csv("data_clean/drivers.csv")

# %%
# Number unique drivers
drivers.to_sql('drivers_sql', 
                con = con, 
                if_exists='replace')
# Out:
# 857

# %%
# Number unique drivers
results.dtypes
# Out:
# resultId             int64
# raceId               int64
# driverId             int64
# constructorId        int64
# number              object
# grid                 int64
# position            object
# positionText        object
# positionOrder        int64
# points             float64
# laps                 int64
# time                object
# milliseconds        object
# fastestLap          object
# rank                object
# fastestLapTime      object
# fastestLapSpeed     object
# statusId             int64
# dtype: object
